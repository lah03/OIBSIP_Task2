# %%
import pandas as pd

data = pd.read_csv("Unemployment in India.csv")

data.columns = data.columns.str.strip()

print(data.head())
print(data.info())
# Out:
#            Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("Unemployment in India.csv")

# Remove extra spaces from column names
data.columns = data.columns.str.strip()

# Convert Date column to datetime
data["Date"] = pd.to_datetime(data["Date"])

# Sort values by date
data = data.sort_values("Date")

# Plot graph
plt.figure(figsize=(12,6))

plt.plot(data["Date"], data["Estimated Unemployment Rate (%)"], marker='o')

plt.title("Unemployment Rate in India During COVID-19")
plt.xlabel("Date")
plt.ylabel("Estimated Unemployment Rate (%)")

plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_5860\79110787.py:11: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Date"] = pd.to_datetime(data["Date"])

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

avg = data.groupby("Region")["Estimated Unemployment Rate (%)"].mean()

avg.plot(kind="bar", figsize=(12,6))

plt.title("Average Unemployment Rate by Region")
plt.ylabel("Unemployment Rate")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

top = data.groupby("Region")["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).head(10)

top.plot(kind="bar")

plt.title("Top 10 States with Highest Unemployment")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.hist(data["Estimated Unemployment Rate (%)"], bins=20)

plt.title("Distribution of Unemployment Rate")
plt.xlabel("Rate")
plt.ylabel("Frequency")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.scatter(data["Estimated Employed"], data["Estimated Unemployment Rate (%)"])

plt.xlabel("Estimated Employed")
plt.ylabel("Unemployment Rate")

plt.title("Employment vs Unemployment")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.boxplot(data["Estimated Unemployment Rate (%)"])

plt.title("Boxplot of Unemployment Rate")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

area_avg = data.groupby("Area")["Estimated Unemployment Rate (%)"].mean()

area_avg.plot(kind="bar")

plt.title("Rural vs Urban Unemployment")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.plot(data["Estimated Labour Participation Rate (%)"])

plt.title("Labour Participation Rate Trend")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

corr = data.corr(numeric_only=True)

sns.heatmap(corr, annot=True)

plt.title("Correlation Heatmap")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

sample = data.groupby("Region")["Estimated Unemployment Rate (%)"].mean().head(5)

plt.pie(sample, labels=sample.index, autopct='%1.1f%%')

plt.title("Unemployment Share by State")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

data["Date"] = pd.to_datetime(data["Date"])

monthly = data.groupby
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_5860\2379785980.py:7: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Date"] = pd.to_datetime(data["Date"])

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

area_avg = data.groupby("Area")["Estimated Unemployment Rate (%)"].mean()

area_avg.plot(kind="bar")

plt.title("Average Unemployment Rate by Area")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.scatter(data["Estimated Labour Participation Rate (%)"], data["Estimated Employed"])

plt.title("Labour Participation vs Employment")
plt.xlabel("Participation Rate")
plt.ylabel("Estimated Employed")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

low = data.groupby("Region")["Estimated Unemployment Rate (%)"].mean().sort_values().head(5)

low.plot(kind="bar")

plt.title("Top 5 Regions with Lowest Unemployment")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

data.boxplot(column="Estimated Unemployment Rate (%)", by="Area")

plt.title("Unemployment Rate by Area")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

region_count = data["Region"].value_counts()

region_count.plot(kind="bar")

plt.title("Number of Records by Region")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

plt.hist(data["Estimated Employed"], bins=20)

plt.title("Employment Distribution")

plt.xlabel("Estimated Employed")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Unemployment in India.csv")
data.columns = data.columns.str.strip()

data["Date"] = pd.to_datetime(data["Date"])

covid = data[data["Date"].dt.year == 2020]

plt.plot(covid["Date"], covid["Estimated Unemployment Rate (%)"])

plt.title("Unemployment Trend in 2020 (COVID Period)")
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_5860\199957683.py:7: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Date"] = pd.to_datetime(data["Date"])
